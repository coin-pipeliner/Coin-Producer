# %%
from kafka import KafkaConsumer
from json import loads

# %%
consumer = KafkaConsumer(
    'test',
    bootstrap_servers = ['localhost:9091', 'localhost:9092', 'localhost:9093'],
    auto_offset_reset = 'earliest',
    enable_auto_commit = True,
    group_id = 'my-group',
    value_deserializer = lambda x: loads(x.decode('utf-8')),
    consumer_timeout_ms = 1000
)

# %%
print('[begin] get consumer list')
for message in consumer:
    print('Topic: %s, Partition: %d, Offset: %d, Key: %s, Value: %s' % (
        message.topic, message.partition, message.offset, message.key, message.value
    ))
print('[end] get consumer list')
# Out:
# [begin] get consumer list
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Input In [4], in <module>
#       1 print('[begin] get consumer list')
# ----> 2 for message in consumer:
#       3     print('Topic: %s, Partition: %d, Offset: %d, Key: %s, Value: %s' % (
#       4         message.topic, message.partition, message.offset, message.key, message.value
#       5     ))
#       6 print('[end] get consumer list')
#
# File /usr/local/lib/python3.9/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File /usr/local/lib/python3.9/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File /usr/local/lib/python3.9/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File /usr/local/lib/python3.9/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File /usr/local/lib/python3.9/site-packages/kafka/consumer/group.py:684, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     680     self._update_fetch_positions(self._subscription.missing_fetch_positions())
#     682 # If data is available already, e.g. from a previous network client
#     683 # poll() call to commit, then just return it immediately
# --> 684 records, partial = self._fetcher.fetched_records(max_records, update_offsets=update_offsets)
#     685 if records:
#     686     # Before returning the fetched records, we can send off the
#     687     # next round of fetches and avoid block waiting for their
#     688     # responses to enable pipelining while the user is handling the
#     689     # fetched records.
#     690     if not partial:
#
# File /usr/local/lib/python3.9/site-packages/kafka/consumer/fetcher.py:344, in Fetcher.fetched_records(self, max_records, update_offsets)
#     342         break
#     343     completion = self._completed_fetches.popleft()
# --> 344     self._next_partition_records = self._parse_fetched_data(completion)
#     345 else:
#     346     records_remaining -= self._append(drained,
#     347                                       self._next_partition_records,
#     348                                       records_remaining,
#     349                                       update_offsets)
#
# File /usr/local/lib/python3.9/site-packages/kafka/consumer/fetcher.py:818, in Fetcher._parse_fetched_data(self, completed_fetch)
#     814 if records.has_next():
#     815     log.debug("Adding fetched record for partition %s with"
#     816               " offset %d to buffered record list", tp,
#     817               position)
# --> 818     unpacked = list(self._unpack_message_set(tp, records))
#     819     parsed_records = self.PartitionRecords(fetch_offset, tp, unpacked)
#     820     last_offset = unpacked[-1].offset
#
# File /usr/local/lib/python3.9/site-packages/kafka/consumer/fetcher.py:473, in Fetcher._unpack_message_set(self, tp, records)
#     469 value_size = len(record.value) if record.value is not None else -1
#     470 key = self._deserialize(
#     471     self.config['key_deserializer'],
#     472     tp.topic, record.key)
# --> 473 value = self._deserialize(
#     474     self.config['value_deserializer'],
#     475     tp.topic, record.value)
#     476 headers = record.headers
#     477 header_size = sum(
#     478     len(h_key.encode("utf-8")) + (len(h_val) if h_val is not None else 0) for h_key, h_val in
#     479     headers) if headers else -1
#
# File /usr/local/lib/python3.9/site-packages/kafka/consumer/fetcher.py:511, in Fetcher._deserialize(self, f, topic, bytes_)
#     509 if isinstance(f, Deserializer):
#     510     return f.deserialize(topic, bytes_)
# --> 511 return f(bytes_)
#
# Input In [2], in <lambda>(x)
#       1 consumer = KafkaConsumer(
#       2     'test',
#       3     bootstrap_servers = ['localhost:9091', 'localhost:9092', 'localhost:9093'],
#       4     auto_offset_reset = 'earliest',
#       5     enable_auto_commit = True,
#       6     group_id = 'my-group',
# ----> 7     value_deserializer = lambda x: loads(x.decode('utf-8')),
#       8     consumer_timeout_ms = 1000
#       9 )
#
# File /usr/local/Cellar/python@3.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /usr/local/Cellar/python@3.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File /usr/local/Cellar/python@3.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
